# %%
import math
import string

# %%
prog_inp = ""
with open("day4_input.txt", "r") as f:
    prog_inp = f.readlines()

prog_inp = [line.rstrip() for line in prog_inp if line != "\n"]
print(prog_inp)
# Out:
# ['test', 'day4!', '123', 'yolo']

# %%
parsed_inp = []
for i, line in enumerate(prog_inp):
    parsed_line = line[:]
    parsed_inp.append(parsed_line)
print(parsed_inp)
# Out:
# ['test', 'day4!', '123', 'yolo']
